# %%
import pandas as pd
d=pd.read_csv('PHASE4_CAMERA_CLASSIFICATION.csv')
d.head()
# Out:
#    Unnamed: 0 prediction_level1               level_2_pred  \
# 0           0     Photo Devices         Mirrorless Cameras
# 1           1       Cam Corders  Traditional Video Cameras
# 2           2     Photo Devices                       DSLR
# 3           3       Cam Corders  Traditional Video Cameras
# 4           4     Photo Devices         Mirrorless Cameras
#
#                 level3_pred                                              id  \
# 0  Non-fullFrame Mirrorless  robertscamera-008a7f761a7996836c0dd575f1760ab6
# 1         Traditional Video  robertscamera-03544e86402ebfdfb82e3a1b87ac1c9b
# 2                      DSLR  robertscamera-03ddd653bb4422f0a040a458a770a5cf
# 3                Prof Video  robertscamera-0482c11ee587a6b78530b61fdffd77a0
# 4  Non-fullFrame Mirrorless  robertscamera-06533827a6d5aeba91b984cb079d555e
#
#                brand                                               name  \
# 0          Panasonic            Panasonic \t\tLumix DMC-GX7 (Body Only)
# ...
